# %% [markdown]
# **My EDA will be looking at the differences between males and females.**

# %%
import pandas as pd
import seaborn as sns
import os
import sys
module_path = os.path.abspath(os.path.join('.'))
if module_path not in sys.path:
    sys.path.append(module_path)
import project_functions1
address = '/Users/rylanvandermeulen/Desktop/course-project-group_1017/Data/Raw/medical_expenses.csv'

# %%
df = project_functions1.load_and_process(address)
df
# Out:
#       age     sex   bmi  children smoker     region      charges
# 0      18    male  16.0         0     no  northeast   1694.79640
# 1      38    male  16.8         2     no  northeast   6640.54485
# 2      21  female  16.8         1     no  northeast   3167.45585
# 3      26  female  17.2         2    yes  northeast  14455.64405
# 4      28  female  17.3         0     no  northeast   3732.62510
# ...   ...     ...   ...       ...    ...        ...          ...
# 1333   46  female  48.1         2     no  northeast   9432.92530
# 1334   58    male  49.1         0     no  southeast  11381.32540
# 1335   23    male  50.4         1     no  southeast   2438.05520
# 1336   22    male  52.6         1    yes  southeast  44501.39820
# 1337   18    male  53.1         0     no  southeast   1163.46270
#
# [1338 rows x 7 columns]

# %%
df.describe(include = 'all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663303     1.094918    NaN        NaN
# std       14.049960   NaN     6.098257     1.205493    NaN        NaN
# min       18.000000   NaN    16.000000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.300000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.100000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    13270.422265
# std     12110.011237
# min      1121.873900
# 25%      4740.287150
# 50%      9382.033000
# 75%     16639.912515
# max     63770.428010

# %%
df_male = df[df['sex']=='male']
df_male
#create a dataframe with just males
# Out:
#       age   sex   bmi  children smoker     region      charges
# 0      18  male  16.0         0     no  northeast   1694.79640
# 1      38  male  16.8         2     no  northeast   6640.54485
# 5      18  male  17.3         2    yes  northeast  12829.45510
# 8      23  male  17.4         1     no  northwest   2775.19215
# 9      19  male  17.5         0     no  northwest   1621.34020
# ...   ...   ...   ...       ...    ...        ...          ...
# 1332   52  male  47.7         1     no  southeast   9748.91060
# 1334   58  male  49.1         0     no  southeast  11381.32540
# 1335   23  male  50.4         1     no  southeast   2438.05520
# 1336   22  male  52.6         1    yes  southeast  44501.39820
# 1337   18  male  53.1         0     no  southeast   1163.46270
#
# [676 rows x 7 columns]

# %%
def average_bmi(df):
    average = df["bmi"].mean()
    print("Average bmi: ",average)
    return

average_bmi(df_male)
# Out:
# Average bmi:  30.943786982248522

# %%
df_female = df[df['sex']=='female']
df_female
# Out:
#       age     sex   bmi  children smoker     region      charges
# 2      21  female  16.8         1     no  northeast   3167.45585
# 3      26  female  17.2         2    yes  northeast  14455.64405
# 4      28  female  17.3         0     no  northeast   3732.62510
# 6      37  female  17.3         2     no  northeast   6877.98010
# 7      21  female  17.4         1     no  southwest   2585.26900
# ...   ...     ...   ...       ...    ...        ...          ...
# 1327   54  female  46.7         2     no  southwest  11538.42100
# 1328   52  female  46.8         5     no  southeast  12592.53450
# 1329   54  female  47.4         0    yes  southeast  63770.42801
# 1331   37  female  47.6         2    yes  southwest  46113.51100
# 1333   46  female  48.1         2     no  northeast   9432.92530
#
# [662 rows x 7 columns]

# %%
average_bmi(df_female)
# Out:
# Average bmi:  30.37688821752266

# %% [markdown]
# **The average bmi of males and females quite similar, although males do have a slightly higher average.**

# %%
def average_charges(df):
    average = df["charges"].mean()
    print("Average charges: ",average)
    return
average_charges(df_male)
# Out:
# Average charges:  13956.751177721893

# %%
average_charges(df_female)
# Out:
# Average charges:  12569.578843835347

# %% [markdown]
# **The average charges between males and females are also similar, but once again the male average is higher.**

# %%
df_male.describe(include = 'all')
# Out:
#                age   sex         bmi    children smoker     region  \
# count   676.000000   676  676.000000  676.000000    676        676
# unique         NaN     1         NaN         NaN      2          4
# top            NaN  male         NaN         NaN     no  southeast
# freq           NaN   676         NaN         NaN    517        189
# mean     38.917160   NaN   30.943787    1.115385    NaN        NaN
# std      14.050141   NaN    6.140219    1.218986    NaN        NaN
# min      18.000000   NaN   16.000000    0.000000    NaN        NaN
# 25%      26.000000   NaN   26.400000    0.000000    NaN        NaN
# 50%      39.000000   NaN   30.700000    1.000000    NaN        NaN
# 75%      51.000000   NaN   35.025000    2.000000    NaN        NaN
# max      64.000000   NaN   53.100000    5.000000    NaN        NaN
#
#              charges
# count     676.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    13956.751178
# std     12971.025915
# min      1121.873900
# 25%      4619.134000
# 50%      9369.615750
# 75%     18989.590250
# max     62592.873090

# %%
df_female.describe(include = 'all')
# Out:
#                age     sex         bmi    children smoker     region  \
# count   662.000000     662  662.000000  662.000000    662        662
# unique         NaN       1         NaN         NaN      2          4
# top            NaN  female         NaN         NaN     no  southeast
# freq           NaN     662         NaN         NaN    547        175
# mean     39.503021     NaN   30.376888    1.074018    NaN        NaN
# std      14.054223     NaN    6.046318    1.192115    NaN        NaN
# min      18.000000     NaN   16.800000    0.000000    NaN        NaN
# 25%      27.000000     NaN   26.100000    0.000000    NaN        NaN
# 50%      40.000000     NaN   30.100000    1.000000    NaN        NaN
# 75%      51.750000     NaN   34.300000    2.000000    NaN        NaN
# max      64.000000     NaN   48.100000    5.000000    NaN        NaN
#
#              charges
# count     662.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    12569.578844
# std     11128.703801
# min      1607.510100
# 25%      4885.158700
# 50%      9412.962500
# 75%     14454.691825
# max     63770.428010

# %% [markdown]
# **It is interesting that both sexes in this dataset are primarily from the southeast**

# %% [markdown]
# **Additionally, it is surpising that 24% of males are smokers while only 17% of females smoke.**

# %%
def plotAvgBmi(df):
    g=sns.lmplot(x='age', y='bmi',data=df, 
          scatter_kws={'s': 100, 'linewidth': 1.0, 'edgecolor': 'w'})
    return g
plotAvgBmi(df_male)
plotAvgBmi(df_female)

# %% [markdown]
# **In these scatterplots you can see the incredible variability among people, as well as the similarity in the pattern or lack of pattern in males and females. Although, there seems to be slightly more variability in females than males**

# %%
def plotAvgCharges(df):
    g=sns.lmplot(x='age', y='charges',data=df, 
          scatter_kws={'s': 100, 'linewidth': 1.0, 'edgecolor': 'w'})
    return g
plotAvgCharges(df_male)
plotAvgCharges(df_female)

# %% [markdown]
# **Once again we see that there isnt a whole lot of difference in the pattern of charges between males and females. However, similar to bmi, the datapoints in the male plot seem to have tighter groupings.**

# %%
df.head(20)
# Out:
#     age     sex   bmi  children smoker     region      charges
# 0    18    male  16.0         0     no  northeast   1694.79640
# 1    38    male  16.8         2     no  northeast   6640.54485
# 2    21  female  16.8         1     no  northeast   3167.45585
# 3    26  female  17.2         2    yes  northeast  14455.64405
# 4    28  female  17.3         0     no  northeast   3732.62510
# 5    18    male  17.3         2    yes  northeast  12829.45510
# 6    37  female  17.3         2     no  northeast   6877.98010
# 7    21  female  17.4         1     no  southwest   2585.26900
# 8    23    male  17.4         1     no  northwest   2775.19215
# 9    19    male  17.5         0     no  northwest   1621.34020
# 10   26    male  17.7         0     no  northwest   2680.94930
# 11   19  female  17.8         0     no  southwest   1727.78500
# 12   32  female  17.8         2    yes  northwest  32734.18630
# 13   35    male  17.9         1     no  northwest   5116.50040
# 14   51  female  18.0         0     no  northwest   9644.25250
# 15   27  female  18.0         2    yes  northeast  15006.57945
# 16   57    male  18.3         0     no  northeast  11534.87265
# 17   60  female  18.3         0     no  northeast  13204.28565
# 18   39  female  18.3         5    yes  southwest  19023.26000
# 19   52  female  18.3         0     no  northwest   9991.03765

# %%
df.tail(20)
# Out:
#       age     sex   bmi  children smoker     region      charges
# 1318   47  female  45.3         1     no  southeast   8569.86180
# 1319   39    male  45.4         2     no  southeast   6356.27070
# 1320   25    male  45.5         2    yes  southeast  42112.23560
# 1321   27    male  45.9         2     no  southwest   3693.42800
# 1322   50  female  46.1         1     no  southeast   9549.56510
# 1323   43  female  46.2         0    yes  southeast  45863.20500
# 1324   32    male  46.5         2     no  southeast   4686.38870
# 1325   37    male  46.5         3     no  southeast   6435.62370
# 1326   26    male  46.5         1     no  southeast   2927.06470
# 1327   54  female  46.7         2     no  southwest  11538.42100
# 1328   52  female  46.8         5     no  southeast  12592.53450
# 1329   54  female  47.4         0    yes  southeast  63770.42801
# 1330   47    male  47.5         1     no  southeast   8083.91980
# 1331   37  female  47.6         2    yes  southwest  46113.51100
# 1332   52    male  47.7         1     no  southeast   9748.91060
# 1333   46  female  48.1         2     no  northeast   9432.92530
# 1334   58    male  49.1         0     no  southeast  11381.32540
# 1335   23    male  50.4         1     no  southeast   2438.05520
# 1336   22    male  52.6         1    yes  southeast  44501.39820
# 1337   18    male  53.1         0     no  southeast   1163.46270

# %% [markdown]
# **Surprisingly even at the extremes of bmi, there is not much of a difference in prevalence of males and females. Females are slightly more represented on the low end and males on the high end, but not in any significant proportion.**
